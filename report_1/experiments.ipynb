# %%
from utils.matrix_helpers import generate_matrix, print_matrix, check_multiplication_correctness
from algorithms.classical import classical_multiply
from algorithms.binet import binet_multiply
from algorithms.hybrid import hybrid_multiply

# %%
matrix1 = generate_matrix(size=8)
matrix2 = generate_matrix(size=8)
print_matrix(matrix1)
print(f'{'-'*9*len(matrix1)}')
print_matrix(matrix2)
# Out:
# 0.213279 0.933855 0.004047 0.102309 0.869565 0.957939 0.074883 0.862052
# 0.762627 0.944256 0.381307 0.576867 0.356674 0.672354 0.919535 0.254859
# 0.267211 0.892458 0.786806 0.396917 0.082040 0.854573 0.050605 0.445916
# 0.422677 0.176427 0.082833 0.976669 0.744029 0.030342 0.045253 0.310121
# 0.297711 0.317211 0.711706 0.098525 0.399949 0.066978 0.776800 0.302475
# 0.019007 0.048702 0.859355 0.774990 0.305310 0.540694 0.877818 0.005741
# 0.988579 0.696327 0.992451 0.581698 0.455154 0.176957 0.938320 0.336026
# 0.432439 0.511807 0.385153 0.480000 0.607412 0.387281 0.671028 0.405959
# ------------------------------------------------------------------------
# 0.181726 0.658168 0.285491 0.949319 0.663316 0.288775 0.237003 0.156242
# 0.909361 0.516918 0.784385 0.897714 0.469166 0.860834 0.259951 0.617072
# 0.069708 0.588274 0.055068 0.798072 0.552089 0.440557 0.286438 0.938850
# 0.027476 0.326034 0.692638 0.348848 0.978043 0.577755 0.786714 0.184135
# ...

# %%
result, flops_cnt = classical_multiply(matrix1, matrix2)
print_matrix(result)
print(f'{flops_cnt=}')
check_multiplication_correctness(matrix1, matrix2, result)
# Out:
# 2.157610 2.726937 2.617314 2.459348 1.649425 1.886682 1.644697 1.939635
# 1.839916 2.695915 2.232259 2.965078 2.184262 2.576671 1.757482 2.088882
# 1.726422 2.210576 2.011065 2.702286 1.614432 1.983953 1.452601 2.271108
# 0.642335 1.670776 1.630909 1.371938 2.081010 1.217906 1.504074 0.759804
# 0.729316 1.700031 0.946710 1.484061 1.275720 1.390953 0.870757 1.442327
# 0.752197 1.774188 1.196270 1.745559 1.645905 1.774601 1.490737 1.646142
# 1.361539 2.880713 1.923859 3.017051 2.611767 2.494474 1.717233 2.285562
# 1.261892 2.270395 1.794414 2.068044 1.873819 1.867967 1.488042 1.621222
# flops_cnt=1024
# True

# %%
binet_multiply_result, binet_flops_cnt = binet_multiply(matrix1, matrix2)
print_matrix(binet_multiply_result)
print(f'{binet_flops_cnt=}')
check_multiplication_correctness(matrix1, matrix2, binet_multiply_result)
# Out:
# 2.157610 2.726937 2.617314 2.459348 1.649425 1.886682 1.644697 1.939635
# 1.839916 2.695915 2.232259 2.965078 2.184262 2.576671 1.757482 2.088882
# 1.726422 2.210576 2.011065 2.702286 1.614432 1.983953 1.452601 2.271108
# 0.642335 1.670776 1.630909 1.371938 2.081010 1.217906 1.504074 0.759804
# 0.729316 1.700031 0.946710 1.484061 1.275720 1.390953 0.870757 1.442327
# 0.752197 1.774188 1.196270 1.745559 1.645905 1.774601 1.490737 1.646142
# 1.361539 2.880713 1.923859 3.017051 2.611767 2.494474 1.717233 2.285562
# 1.261892 2.270395 1.794414 2.068044 1.873819 1.867967 1.488042 1.621222
# binet_flops_cnt=960
# True

# %%
task_1_result, task_1_flops_cnt = hybrid_multiply(matrix1, matrix2,2)
print_matrix(task_1_result)
print(f'{task_1_flops_cnt=}')
check_multiplication_correctness(matrix1, matrix2, task_1_result)
# Out:
# 2.157610 2.726937 2.617314 2.459348 1.649425 1.886682 1.644697 1.939635
# 1.839916 2.695915 2.232259 2.965078 2.184262 2.576671 1.757482 2.088882
# 1.726422 2.210576 2.011065 2.702286 1.614432 1.983953 1.452601 2.271108
# 0.642335 1.670776 1.630909 1.371938 2.081010 1.217906 1.504074 0.759804
# 0.729316 1.700031 0.946710 1.484061 1.275720 1.390953 0.870757 1.442327
# 0.752197 1.774188 1.196270 1.745559 1.645905 1.774601 1.490737 1.646142
# 1.361539 2.880713 1.923859 3.017051 2.611767 2.494474 1.717233 2.285562
# 1.261892 2.270395 1.794414 2.068044 1.873819 1.867967 1.488042 1.621222
# task_1_flops_cnt=960
# True

# %%
task_1_result, task_1_flops_cnt = hybrid_multiply(matrix1, matrix2,4)
print_matrix(task_1_result)
print(f'{task_1_flops_cnt=}')
check_multiplication_correctness(matrix1, matrix2, task_1_result)
# Out:
# 2.157610 2.726937 2.617314 2.459348 1.649425 1.886682 1.644697 1.939635
# 1.839916 2.695915 2.232259 2.965078 2.184262 2.576671 1.757482 2.088882
# 1.726422 2.210576 2.011065 2.702286 1.614432 1.983953 1.452601 2.271108
# 0.642335 1.670776 1.630909 1.371938 2.081010 1.217906 1.504074 0.759804
# 0.729316 1.700031 0.946710 1.484061 1.275720 1.390953 0.870757 1.442327
# 0.752197 1.774188 1.196270 1.745559 1.645905 1.774601 1.490737 1.646142
# 1.361539 2.880713 1.923859 3.017051 2.611767 2.494474 1.717233 2.285562
# 1.261892 2.270395 1.794414 2.068044 1.873819 1.867967 1.488042 1.621222
# task_1_flops_cnt=1024
# True
